# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("customer_churn.csv")
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1736  7551-JOHTI  Female              0      No         No       1
# 89    3016-KSVCP    Male              0     Yes         No      29
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 1762  9470-XCCEM    Male              0     Yes        Yes      35
# 6530  0230-UBYPQ    Male              1     Yes         No      63
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1736          Yes                No              No  No internet service  ...
# 89             No  No phone service             DSL                   No  ...
# 4380          Yes                No              No  No internet service  ...
# 1762          Yes               Yes     Fiber optic                   No  ...
# 6530           No  No phone service             DSL                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...
